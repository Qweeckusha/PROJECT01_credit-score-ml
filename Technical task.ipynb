# %% [markdown]
# # МЛ Практика 6 — Итоговое творческое задание (18/100 баллов)
#
# ## Контекст курса
# В Практиках 1–5 вы прошли ключевые компоненты ML-проекта:
# - EDA и типы переменных (Практика 1)
# - регрессия, метрики, базовое моделирование, подбор параметров (Практика 2)
# - классификация, энкодеры, метрики (Практика 3)
# - кластеризация и обучение без учителя (Практика 4)
# - пайплайны, ColumnTransformer, кросс-валидация, отбор признаков (Практика 5.1)
# - обработка текста, векторизация/Word2Vec, kNN/деревья (Практика 5.2)
#
# Практика 6 — это мини-проект, где важно не только обучить модель, но и объяснить результат и защитить его в презентации.
#
# ---
#
# ## Цель задания
# Собрать законченный ML-проект:
# 1) постановка задачи и выбор метрик
# 2) подготовка и анализ данных
# 3) обучение минимум двух моделей (baseline + улучшение)
# 4) оценка качества + анализ ошибок/интерпретация
# 5) презентация результата (обязательный итоговый артефакт)
#
# ## Что нужно сделать (обязательные требования)
#
# ### 1) Выберите тип задачи
# Можно выбрать один трек или комбинировать:
#
# Трек A — Регрессия (табличные данные)
# Пример: предсказание цены/рейтинга/времени/спроса.
#
# Трек B — Классификация (табличные или текстовые данные)
# Пример: спам/тональность/отток/категория товара/качество.
#
# Трек C — Кластеризация (без учителя)
# Пример: сегментация пользователей/товаров/текстов + интерпретация сегментов.
#
# Трек D — Смешанный проект (рекомендуется для "творческой" части)
# Примеры:
# - кластеризация текстов + классификация "кластера" + вывод top-5 ближайших соседей по эмбеддингам;
# - кластеризация объектов → отдельная модель регрессии/классификации внутри каждого кластера;
# - классификация + блок объяснения (важные признаки) + рекомендации по улучшению данных.
#
# ---
#
# ### 2) Данные
# - Используйте реальный датасет: Kaggle / открытые данные / датасеты по смыслу из предыдущих практик.
# - Минимально в отчёте/ноутбуке:
#   - источник данных
#   - размерность (строки/признаки), типы признаков
#   - пропуски/дубликаты/аномалии/дисбаланс (если есть)
#
# ---
#
# ### 3) EDA и подготовка
# - Минимум: 2–4 осмысленных вывода по данным (распределения, связь с целевой, дисбаланс, выбросы, текстовые особенности).
# - Подготовка признаков по типу данных:
#   - числовые: обработка пропусков, при необходимости масштабирование
#   - категориальные: OHE/OrdinalEncoder (по смыслу)
#   - текст: очистка + TF-IDF/Word2Vec/эмбеддинги (на выбор)
#
# ---
#
# ### 4) Обучение моделей (минимум 2)
# - Baseline: простая модель (линейная регрессия/логистическая регрессия/kNN/простое дерево и т.п.)
# - Улучшенная модель: другой алгоритм и/или признаки и/или подбор параметров (GridSearchCV/RandomizedSearchCV)
# - Желательно (как в Практике 5.1): оформить через Pipeline + ColumnTransformer.
#
# ---
#
# ### 5) Оценка качества и объяснение результата
# Выберите метрики по задаче и объясните их смысл:
# - регрессия: MAE/RMSE/R² (минимум 2 метрики)
# - классификация: F1/ROC-AUC/PR-AUC + confusion matrix (по смыслу)
# - кластеризация: silhouette/davies-bouldin + визуализация (PCA при желании) + интерпретация кластеров
#
# Обязательно включить:
# - таблицу "baseline vs финальная модель"
# - анализ ошибок/сложных кейсов (минимум 3–5 примеров)
# - блок интерпретации:
#   - для табличных: feature importance / коэффициенты / permutation importance
#   - для текста/кластеров: топ-слова/примеры документов/характеристика кластеров
#
# ---
#
# ## Опционально (разрешено и приветствуется): мини-сервис на FastAPI
# Можно сделать простой inference-сервис:
# - `POST /predict` — принимает JSON и возвращает предсказание
#
# Сервис не обязателен, но учитывается в критериях как "инженерная упаковка".
# ---
#
# ## Что сдаём (артефакты)
# 1) Презентация (обязательно): `PDF` или `PPTX`, 7–12 слайдов
# 2) Код:
#    - ноутбук `.ipynb` или репозиторий со скриптами
# 3) (если есть FastAPI) — код сервиса + инструкция запуска
#
# Рекомендуемая структура репозитория:
# - `notebook.ipynb` или `src/`
# - `README.md` (как запустить, что внутри)
# - `requirements.txt`
# - `presentation.pdf` (или `.pptx`)
# - `models/` (если сохраняете модель)
#
# ---
#
# ## Требования к презентации (рекомендуемый шаблон)
# 1. Тема проекта + автор
# 2. Постановка задачи (что решаем и зачем)
# 3. Данные (источник, объём, признаки, проблемы)
# 4. EDA: 2–3 ключевых наблюдения
# 5. Baseline: подход + метрики
# 6. Улучшение: что сделали и почему
# 7. Сравнение моделей (таблица метрик)
# 8. Интерпретация результата (важные признаки/кластеры/примеры)
# 9. Анализ ошибок (3–5 кейсов)
# 10. Итоговые выводы + что улучшать дальше
# 11. (опционально) Демонстрация API/сервиса
#
# ---
#
# # Критерии оценки (18 баллов)
#
# ## 1) Постановка задачи и корректность формализации — 2 балла
# - 2: задача сформулирована ясно (X→y / кластеры), понятен практический смысл, выбран корректный тип задачи и критерии успеха
# - 1: формально верно, но смысл/ограничения/успех описаны поверхностно
# - 0: постановка расплывчатая или противоречивая (непонятно, что прогнозируем и зачем)
#
# ## 2) Данные и EDA — 3 балла
# - 3: источник/описание данных + осмысленный EDA (выводы, графики/таблицы), выявлены ключевые проблемы
# - 2: EDA есть, но выводы слабые или проблемы данных почти не учтены
# - 1: минимальное описание без анализа
# - 0: EDA отсутствует
#
# ## 3) Подготовка данных и отсутствие утечек — 3 балла
# - 3: корректная предобработка по типам признаков + корректный split/CV без утечек; воспроизводимость (seed)
# - 2: предобработка в целом есть, но есть спорные места (частичная утечка/неочевидные преобразования)
# - 1: предобработка минимальна и/или сильно ручная без контроля качества
# - 0: предобработка некорректна (ошибки, утечки, несогласованность train/test)
#
# ## 4) Моделирование: baseline + улучшение — 4 балла
# - 4: baseline измерен; улучшенная модель обоснована и сравнима; есть тюнинг/признаки/алгоритм; сравнение честное
# - 3: baseline и финальная есть, но улучшение слабо обосновано или сравнение неполное
# - 2: две модели есть, но фактически без анализа разницы
# - 1: только одна модель или "улучшение" не показано
# - 0: модели/результатов нет
#
# ## 5) Метрики и качество оценки — 3 балла
# - 3: метрики выбраны правильно, интерпретированы; есть матрица ошибок/анализ остатков/валидирующая схема
# - 2: метрики есть, но интерпретация слабая или схема оценки неубедительна
# - 1: метрики формально приведены без понимания
# - 0: метрики отсутствуют или нерелевантны задаче
#
# ## 6) Объяснение результата и анализ ошибок — 2 балла
# - 2: интерпретация (важные признаки/кластеры/примеры) + 3–5 кейсов ошибок/сложных примеров с выводами
# - 1: либо интерпретация, либо ошибки, но не оба блока полноценно
# - 0: нет объяснения результата
#
# ## 7) Презентация и защита — 1 балл
# - 1: логичная структура, читаемость, выводы соответствуют метрикам и графикам
# - 0: презентация отсутствует или не позволяет понять, что сделано и какие результаты
#
# ### Инженерный бонус (до +2)
# - +0.5: аккуратная упаковка (README, requirements, сохранение модели, понятный запуск)
# - +0.5: FastAPI (или аналогичный inference-скрипт/демо), корректно работающий по инструкции
#
#
# ### Случайный бонус за смекалку 🤘
